# %%
import numpy as np
l=[1,2,3,4,5]
l1=[2,3,5,4,5]
n=np.array(l)
n1=np.array(l1)
print(n)
print(n1)
# Out:
# [1 2 3 4 5]
# [2 3 5 4 5]

# %%
type(n1)
type(n)
# Out:
# numpy.ndarray

# %%
import numpy as np
print(n+n1)
print(n*n1)
# Out:
# [ 3  5  8  8 10]
# [ 2  6 15 16 25]

# %%
print("array2 multiplied by array1: ",n*n1)
print("array2 divided by array1: ",n/n1)
print("array2 raised to the power of array1: ",n**n1)
# Out:
# array2 multiplied by array1:  [ 2  6 15 16 25]
# array2 divided by array1:  [0.5        0.66666667 0.6        1.         1.        ]
# array2 raised to the power of array1:  [   1    8  243  256 3125]

# %%
print(np.log(n))
print(np.sin(n))
print(np.cos(n))
print(np.tan(n))
# Out:
# [0.         0.69314718 1.09861229 1.38629436 1.60943791]
# [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# [ 0.54030231 -0.41614684 -0.9899925  -0.65364362  0.28366219]
# [ 1.55740772 -2.18503986 -0.14254654  1.15782128 -3.38051501]

# %%
people=['kiran','arun','vijay','varun']
age=[25,30,35,40]
heigth=[145,151,165,173]
weigth=[45,55,65,75]
import matplotlib.pyplot as plt
#plt.plot(age,heigth)
plt.scatter(age,heigth)
#plt.xlabel('age')
#plt.ylabel('height')
plt.title('age vs heigth')
plt.show()

# %%
plt.bar(people,age)
plt.show()

# %%
plt.hist(age)
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("/content/akhila.zip")
df1
# Out:
#    f1  f2  f3
# 0  22  33  44

# %%
data2 = pd.read_csv("/content/HistoricalPrices.csv")
data2
# Out:
#         Date      Open      High       Low     Close
# 0   08/07/24  39230.09  39477.96  38731.51  38763.45
# 1   08/06/24  38736.22  39449.53  38638.30  38997.66
# 2   08/05/24  39056.19  39056.19  38499.27  38703.27
# 3   08/02/24  40075.33  40075.33  39358.68  39737.26
# 4   08/01/24  40916.96  41096.66  40098.57  40347.97
# ..       ...       ...       ...       ...       ...
# 56  05/16/24  39912.34  40051.05  39864.68  39869.38
# 57  05/15/24  39615.10  39935.04  39615.10  39908.00
# 58  05/14/24  39466.76  39616.41  39371.92  39558.11
# 59  05/13/24  39591.28  39647.39  39403.05  39431.51
# 60  05/10/24  39466.52  39579.88  39406.26  39512.84
#
# [61 rows x 5 columns]

# %%
data3 = pd.read_excel("/content/sample3.xlsx")
data3
# Out:
#      ID    Months  Unnamed: 2 ListMonths  Unnamed: 4  Unnamed: 5    Unnamed: 6
# 0   1.0   January         NaN    January         NaN         NaN  Select Month
# 1   2.0  February         NaN   February         NaN         NaN        August
# 2   3.0     March         NaN      March         NaN         NaN           NaN
# 3   4.0     April         NaN      April         NaN         NaN           NaN
# 4   NaN       NaN         NaN       June         NaN         NaN           NaN
# 5   5.0      June         NaN       July         NaN         NaN           NaN
# 6   6.0      July         NaN     August         NaN         NaN           NaN
# 7   7.0    August         NaN    October         NaN         NaN           NaN
# 8   NaN       NaN         NaN   December         NaN         NaN           NaN
# 9   8.0   October         NaN        NaN         NaN         NaN           NaN
# 10  NaN       NaN         NaN        NaN         NaN         NaN           NaN
# ...
